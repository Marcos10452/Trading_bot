# %%
#https://www.alphavantage.co/documentation/#intelligence

# %%
import pandas as pd
import requests

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=MARKET_STATUS&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)

# %%
# converting json dataset from dictionary to dataframe
data_df = pd.json_normalize(data['markets'])

# %%
data_df

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=demo'
r = requests.get(url)
data = r.json()

# %%
#Save as json
import json
import re

# %%
with open("test.json", 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
# Opening JSON file
f = open('test.json')

# returns JSON object as
# a dictionary
data = json.load(f)

# %%
# Closing file
f.close()

# %%
# with open('test.json', 'r') as handle:
#     text_data = handle.read()
#     text_data = '[' + re.sub(r'\}\s\{', '},{', text_data) + ']'
#     json_data = json.loads(text_data)

# %%
# # Closing file
# handle.close()

# %%
data_df = pd.json_normalize(data['feed'])

# %%
data_df[data_df['overall_sentiment_label']=='Bullish']

# %%
data_df['overall_sentiment_label'].value_counts()

# %%
recs = data['feed']

# %%
import json
recs = json.dumps(data['feed'])

# %%
recs=data['feed'][35]

# %%
recs=recs['ticker_sentiment']

# %%
data_df = pd.json_normalize(recs['ticker_sentiment'])
data_df

# %%
data['feed']

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://alphavantageapi.co/timeseries/analytics?SYMBOLS=AAPL,MSFT,IBM&RANGE=2023-07-01&RANGE=2023-08-31&INTERVAL=DAILY&OHLC=close&CALCULATIONS=MEAN,STDDEV,CORRELATION&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)

# %%
data_df = pd.json_normalize(data)

# %%
data_df

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://alphavantageapi.co/timeseries/running_analytics?SYMBOLS=AAPL,IBM&RANGE=2month&INTERVAL=DAILY&OHLC=close&WINDOW_SIZE=20&CALCULATIONS=MEAN,STDDEV(annualized=True)&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)

# %%
data_df = pd.json_normalize(data['payload'])

# %%
data_df

# %%
recs = data['payload']['RETURNS_CALCULATIONS']['MEAN']['RUNNING_MEAN']
data_df = pd.json_normalize(recs)
data_df

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key

data=pd.read_json("test.json")

print(data)

# %%
#************************ Definitions **************

BASE_URL = 'https://www.alphavantage.co/query'
API_KEY = 'TFHNYCWBD71JBSON'
#https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=aapl&interval=60min&apikey=TFHNYCWBD71JBSON&datatype=json
STOCK_FN = 'TIME_SERIES_DAILY' 
OUTPUTSIZE='full' # "compact" returns only the latest 100 data points; "full" returns the full-length time series of 20+
#STOCK_FN = 'TIME_SERIES_DAILY_ADJUSTED' #Premium endpoint not possible to use.
#TIME_SERIES_INTRADAY interval=5min

# %%
# »»»»»»»»»»»»»»»»» STOCKS ««««««««««««««««««««z

# STOCKS={'amazon':'AMZN','apple':'AAPL','netflix':'NFLX','google':'GOOG','Accenture':'ACN',
#        'alibaba':'BABA','Turtle Beach':'HEAR','Disney':'DIS',
#        'LG Display':'LPL','microsoft':'MICS','sony':'SONY',
#        'Cenovus Energy':'CVE','YPF':'YPF','SHELL':'SHEL','Petrobras':'PBR',
#        'Coca-Cola':'KO','PespsiCo':'PEP','Unilever':'UL','Kimberly-Clark':'KMB',
#        'Mondelez':'MDLZ'}

STOCKS = {'apple':'AAPL'}
STOCK_NAME='APPL'
DATE_FROM='20220110T0130'
DATE_TO='20220210T0130'

# dir where parquete file will be created
stocks_dir = '/dataset/stocks_aux/'

#*****************************************************************


stock_df=pd.DataFrame()
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'{BASE_URL}?function=NEWS_SENTIMENT&tickers=AAPL&&topics=technology&limit=1000&time_from={DATE_FROM}&time_to={DATE_TO}&apikey={API_KEY}'
r = requests.get(url)
data = r.json()

# %%
data_df = pd.json_normalize(data['feed'])

# %%
#data_df=data_df[['title','time_published','overall_sentiment_score']]

# %%
data_df.to_csv(f'./get_data/Sentiment/sentiment_{STOCK_NAME}_{DATE_FROM}_{DATE_TO}.CSV')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 data_df.to_csv(f'./get_data/Sentiment/sentiment_{STOCK_NAME}_{DATE_FROM}_{DATE_TO}.CSV')
#
# NameError: name 'data_df' is not defined

# %%
data

# %%
list_date=['20220210T0130','20220310T0130','20220410T0130','20220510T0130','20220610T0130','20220710T0130','20220810T0130','20220910T0130',
           '20221010T0130','20221110T0130','20221210T0130',
           '20230110T0130','20230210T0130','20230310T0130','20230410T0130','20230510T0130','20230610T0130','20230710T0130','20230810T0130',
           '20230910T0130','20231010T0130','20231110T0130','20231210T0130','20240110T0130']
STOCK_NAME='APPL'

# %%
append_df=pd.DataFrame()
for i,date in enumerate(list_date):
    if i<len(list_date)-1:
        read_df=pd.read_csv(f'./get_data/Sentiment/sentiment_{STOCK_NAME}_{date}_{list_date[i+1]}.CSV')
        append_df=append_df._append(read_df)#for pandas has changed "append" to "_append". or you have to use concatenate

# %%
append_df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Amazon's stock is about to get much, much cheaper
# 1             1  Here's What Social Media Had to Say About Appl...
# 2             2  These 3 Household Tech Stocks Can Give Your Po...
# 3             3  Amazon's stock is about to get much, much cheaper
# 4             4  Amazon Announces 20-For-1 Stock Split, Share B...
# ..          ...                                                ...
# 674         674  GM's Infotainment Product Head Reveals Main Re...
# 675         675  Tim Sweeney's Credibility Trumps Sundar Pichai...
# 676         676  How Did Epic Games' Showdown With Google Diffe...
# 677         677  Google Court Ruling Spurs Analyst Opinions - W...
# 678         678  Elon Musk's X 2023 Faces Anticipated Ad Revenu...
#
#                                                    url   time_published  \
# 0    https://edition.cnn.com/2022/03/09/investing/a...  20220310T011643
# ...

# %%
from datetime import datetime

# %%
datetime.strptime('20231213T085331', '%Y%m%dT%H%M%S').date()
# Out:
# datetime.date(2023, 12, 13)

# %%
append_df['date']=append_df['time_published'].apply(lambda x: datetime.strptime(x, '%Y%m%dT%H%M%S').date())

# %%
append_df
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Amazon's stock is about to get much, much cheaper
# 1             1  Here's What Social Media Had to Say About Appl...
# 2             2  These 3 Household Tech Stocks Can Give Your Po...
# 3             3  Amazon's stock is about to get much, much cheaper
# 4             4  Amazon Announces 20-For-1 Stock Split, Share B...
# ..          ...                                                ...
# 674         674  GM's Infotainment Product Head Reveals Main Re...
# 675         675  Tim Sweeney's Credibility Trumps Sundar Pichai...
# 676         676  How Did Epic Games' Showdown With Google Diffe...
# 677         677  Google Court Ruling Spurs Analyst Opinions - W...
# 678         678  Elon Musk's X 2023 Faces Anticipated Ad Revenu...
#
#                                                    url   time_published  \
# 0    https://edition.cnn.com/2022/03/09/investing/a...  20220310T011643
# ...

# %%
append_df.sort_values(by=['date'],inplace=True)

# %%
append_df.reset_index(drop=True,inplace=True)

# %%
append_df
# Out:
#        Unnamed: 0                                              title  \
# 0             164  US stocks fall, oil tops $105 as Ukraine crisi...
# 1             162  Russia says its economy is taking 'serious blo...
# 2             163  Apple halts product sales in Russia after Ukra...
# 3             161  Rich Russians turn to luxury jewellery, watche...
# 4             158    Are You an Investor Needing Some Calm Guidance?
# ...           ...                                                ...
# 14739          12  The Zacks Analyst Blog Highlights Apple, Unite...
# 14740          19  Nasdaq, S&P 500 Futures Dip; Oil, Bitcoin Surg...
# 14741           2  Podcast Market size to grow by USD 15.70 billi...
# 14742           1  Podcast Market size to grow by USD 15.70 billi...
# 14743           0  10 predictions for stocks, crypto, AI, gold an...
#
#                                                      url   time_published  \
# ...

# %%
append_df.to_csv('./get_data/Sentiment/Overall_sentiment_20240121.csv')
